constructed":true},{"name":"100_0087_0076.JPG","position":{"x":-1.8214115130400002,"y":-24.16367310007,"z":0.08095384924000011},"rotation":[[-0.99830404,0.04751123,0.03364114],[-0.04531434,-0.99696513,0.06330201],[0.0365466,0.06167022,0.99742726]],"reconstructed":true},{"name":"100_0087_0115.JPG","position":{"x":-37.71072439473001,"y":-12.639177145480001,"z":0.0494138632899996},"rotation":[[0.97907092,-0.19531712,0.05719573],[0.1933324,0.98037985,0.03844394],[-0.06358231,-0.02658156,0.99762253]],"reconstructed":true},{"name":"100_0087_0116.JPG","position":{"x":-37.83472016822,"y":3.11721821186,"z":0.04059470076999938},"rotation":[[0.98251189,-0.17407208,0.06610061],[0.17188235,0.98440246,0.0375266],[-0.07160193,-0.0255088,0.99710705]],"reconstructed":true},{"name":"100_0087_0119.JPG","position":{"x":-56.74463623098,"y":25.399343651309998,"z":-0.030978494370000203},"rotation":[[0.14831114,0.98798644,0.04343496],[-0.98805379,0.14617539,0.04881045],[0.04187494,-0.05015521,0.99786319]],"reconstructed":true},{"name":"100_0087_0120.JPG","position":{"x":-71.97740970086001,"y":25.40005193056,"z":0.028769317679999976},"rotation":[[0.16458235,0.97935186,-0.11739924],[-0.9845977,0.1702383,0.0398282],[0.05899167,0.109036,0.99228581]],"reconstructed":true},{"name":"100_0087_0122.JPG","position":{"x":-73.67918032327002,"y":6.68130691518,"z":-0.0392569563899996},"rotation":[[-0.99188309,0.12537931,0.02116511],[-0.12381727,-0.99026399,0.06361226],[0.02893471,0.06047532,0.99775023]],"reconstructed":true},{"name":"100_0087_0123.JPG","position":{"x":-73.68597570563001,"y":-8.85393363408,"z":-0.01635901524000043},"rotation":[[-0.99457293,0.10025169,0.02782594],[-0.09823479,-0.99295496,0.06625993],[0.03427258,0.06316686,0.99741433]],"reconstructed":true},{"name":"100_0087_0124.JPG","position":{"x":-73.56590455934,"y":-24.66373229941,"z":0.0007337732700001696},"rotation":[[-0.99730156,0.06906536,0.02489125],[-0.06741803,-0.99580576,0.06185227],[0.0290587,0.06000725,0.99777489]],"reconstructed":true}]}'    

    bundle_data = json.loads(bundle_data_str)
    camera = bundle_data['camera']
    f = camera['focal_length']
    x_c = camera['xo']
    y_c = camera['yo']
    width = camera['pixel_width']
    height = camera['pixel_height']
    k1 = camera['k1']
    k2 = camera['k2']
    k3 = camera['k3']
    t1 = camera['t1']
    t2 = camera['t2']

    views = bundle_data['images']
    n_views = len(views)
    views_pos = np.array([[view['position']['x'], view['position']['y'], view['position']['z']] for view in views])
    views_rot = np.array([view['rotation'] for view in views])

# %%
if False:
    from utils.uni_io.bundle_out import read_bundle_out

    bundle_out_file = '/home/zoltan/Repo/pix/.launch_stack/heavy_compute_node/.scratch/task0/965ba51e-14cc-4179-82c0-2c7832ecda4c/bundle_a8091b66-5f5a-4404-b3bb-00530b030008.out'
    cam, R, tran, [x,y,z], [x_mean, y_mean, z_mean], cam_view_pt, n_view_pt = read_bundle_out(bundle_out_file)

    f = cam.f[0]
    x_c = cam.xo[0]
    y_c = cam.xo[0]
    width = float(cam.size_x[0])
    height = float(cam.size_y[0])
    k1 = float(cam.k1[0])
    k2 = float(cam.k2[0])
    k3 = float(cam.k3[0])
    t1 = float(cam.t1[0])
    t2 = float(cam.t2[0])

    n_views = len(cam.name)
    views_pos = cam.pos
    views_rot = np.array([R[:, :, k] for k in range(R.shape[2])])

# %%
plt.figure(figsize=(6,5))
ax = plt.axes(projection='3d')
ax.scatter3D(views_pos[:,0], views_pos[:,1], views_pos[:,2], c='r', s=10)
ax.scatter3D(P_w[0], P_w[1], P_w[2], c='b', s=10)
for k in range(n_views):
    plot_fustrum(ax, views_pos[k], views_rot[k], f=-1.0, scale=10)
set_3d_axes_equal(ax)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
backprojections = []
for k in range(n_views):
    R = views_rot[k];
    C = views_pos[k]
    P_c = R @ P_w - R @ C
    p_n = [-P_c[0]/P_c[2], -P_c[1]/P_c[2]]

    r2 = p_n[0] * p_n[0] + p_n[1] * p_n[1];    
    rp = 1 + k1*r2 + k2*r2*r2 + k3*r2*r2*r2;
    
    px = f * p_n[0] * rp;
    py = f * p_n[1] * rp;

    tx = t2 * (r2 + 2 * p_n[0] * p_n[0]) - 2 * t1 * p_n[0] * p_n[1];
    ty = - t1 * (r2 + 2 * p_n[1] * p_n[1]) + 2 * t2 * p_n[0] * p_n[1];

    x = px + f*tx + x_c + width/2.0;
    y = height/2.0 - (py + f*ty + y_c);
    
    if x >= 0 and x <= width and y >= 0 and y <= height:
        backprojections.append(k)
        print(k, views[k]['name'], r2, rp)
# Out:
# 2 100_0087_0027.JPG 0.13815706155824914 0.9636646272248779
# 3 100_0087_0028.JPG 0.01877595547695534 0.9947790641390066
# 4 100_0087_0066.JPG 0.1874174937212301 0.9518044613125187
# 5 100_0087_0067.JPG 0.2829320076151097 0.9302735387562288
# 6 100_0087_0068.JPG 0.5659660064463079 0.875776847320093
# 12 100_0087_0115.JPG 2.6572540756718177 0.35568858020369276
# 13 100_0087_0116.JPG 2.842627479542967 0.25127825555248795

# %%
plt.figure(figsize=(6,5))
ax = plt.axes(projection='3d')
ax.scatter3D(views_pos[:,0], views_pos[:,1], views_pos[:,2], c='r', s=10)
ax.scatter3D(P_w[0], P_w[1], P_w[2], c='b', s=10)
for k in range(n_views):
    plot_fustrum(ax, views_pos[k], views_rot[k], f=-1.0, scale=10)
for cam_idx in backprojections:
    ax.plot3D([P_w[0], views_pos[cam_idx,0]], 
                 [P_w[1], views_pos[cam_idx,1]], 
                 [P_w[2], views_pos[cam_idx, 2]], 'b-')
set_3d_axes_equal(ax)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Note that there are not possible appearances in images. Let's investigate why that happened?

# %%
cam_idx = backprojections[0]
R = views_rot[cam_idx]
C = views_pos[cam_idx]

plt.figure(figsize=(6,5))
ax = plt.axes(projection='3d')
plot_fustrum(ax, C, R, f=-1.0, scale=10)
ax.scatter3D(P_w[0], P_w[1], P_w[2], c='b', s=10)
set_3d_axes_equal(ax)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
P_c = R @ P_w - R @ C

plt.figure(figsize=(6,5))
ax = plt.axes(projection='3d')
plot_fustrum(ax, [0, 0, 0], np.eye(3), f=-1.0, scale=10)
ax.scatter3D(P_c[0], P_c[1], P_c[2], c='b', s=10)
set_3d_axes_equal(ax)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
cam_idx = backprojections[5]
R = views_rot[cam_idx]
C = views_pos[cam_idx]
P_c = R @ P_w - R @ C
p_n = [-P_c[0]/P_c[2], -P_c[1]/P_c[2]]
px_abs = np.abs(p_n[0])

rp_fn = lambda r: 1 + k1*r**2 + k2*r**4 + k3*r**6
r2_test = np.arange(0, 2, 0.001)

plt.figure(figsize=(10,5))
plt.axhline(width/2, c='r', linestyle='--', label='image width')
plt.axhline(-width/2, c='r', linestyle='--')
plt.axhline(px_abs*f, c='g', label='distorted point')
plt.axhline(np.abs(px_abs*rp_fn(px_abs)*f), c='k', label= 'undistorted point')

plt.plot(r2_test, r2_test*rp_fn(r2_test)*f, label='distortion function on point')
plt.axvline(px_abs, c='g')

plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure(figsize=(10,5))
plt.axhline(width/2, c='r', linestyle='--', label='image width')
plt.axhline(-width/2, c='r', linestyle='--')
plt.axhline(px_abs*f, c='g', label='distorted point')
plt.axhline(np.abs(px_abs*rp_fn(px_abs)*f), c='k', label= 'undistorted point')

plt.plot(r2_test, r2_test*rp_fn(r2_test)*f, label='distortion function on point')
plt.axvline(px_abs, c='g')

# more explanation
plt.axvline(width/(2*f), c='r', linestyle=':')
plt.plot(r2_test, r2_test*f, 'b:')

# x*r(x)*f = width/2
# x*r(x) = width/(2*f)
# k1*x^3 + k2*x^5 + k3*x^7 + x - width/(2*f) = 0
rts = np.roots([k3, 0, k2, 0, k1, 0, 1, -width/(2*f)])
rts = np.real(rts[np.isreal(rts)])
rts = rts[rts > 0]
r_lim = np.min(rts)
print(r_lim)
plt.plot(r_lim, r_lim*rp_fn(r_lim)*f, 'bo')

# derivative: 3*k1*x^2 + 5*k2*x^4 + 7*k3*x^6 + 1 = 0
# or: 3*k1*x_2 + 5*k2*x_2^2 + 7*k3*x_2^3 + 1 = 0
# x_2*(3*k1 + 5*k2*x_2 + 7*k3*x_2^2) + 1 = 0

plt.legend()
# Out:
# 0.8856772585493669
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Conclusion: We also need to check whether the normalized coordinates are within the image limits, because
# the radial distortion can pull back a far point to the image limits if the lens is close to fisheye

# %%
backprojections = []
for k in range(n_views):
    R = views_rot[k];
    C = views_pos[k]
    P_c = R @ P_w - R @ C
    p_n = [-P_c[0]/P_c[2], -P_c[1]/P_c[2]]

    r2 = p_n[0] * p_n[0] + p_n[1] * p_n[1];    
    rp = 1 + k1*r2 + k2*r2*r2 + k3*r2*r2*r2;
    
    px = f * p_n[0] * rp;
    py = f * p_n[1] * rp;

    tx = t2 * (r2 + 2 * p_n[0] * p_n[0]) - 2 * t1 * p_n[0] * p_n[1];
    ty = - t1 * (r2 + 2 * p_n[1] * p_n[1]) + 2 * t2 * p_n[0] * p_n[1];

    x = px + f*tx + x_c + width/2.0;
    y = height/2.0 - (py + f*ty + y_c);
    
    if (x >= 0 and x <= width and y >= 0 and y <= height and 
            f*p_n[0] > -width/2.0*1.25 and f*p_n[0] < width/2.0*1.25 and
            f*p_n[1] > -height/2.0*1.25 and f*p_n[1] < height/2.0*1.25):
        backprojections.append(k)
        print(k, views[k]['name'], r2, rp)
# Out:
# 2 100_0087_0027.JPG 0.13815706155824914 0.9636646272248779
# 3 100_0087_0028.JPG 0.01877595547695534 0.9947790641390066
# 4 100_0087_0066.JPG 0.1874174937212301 0.9518044613125187
# 5 100_0087_0067.JPG 0.2829320076151097 0.9302735387562288
# 6 100_0087_0068.JPG 0.5659660064463079 0.875776847320093

# %%
plt.figure(figsize=(6,5))
ax = plt.axes(projection='3d')
ax.scatter3D(views_pos[:,0], views_pos[:,1], views_pos[:,2], c='r', s=10)
ax.scatter3D(P_w[0], P_w[1], P_w[2], c='b', s=10)
for k in range(n_views):
    plot_fustrum(ax, views_pos[k], views_rot[k], f=-1.0, scale=10)
for cam_idx in backprojections:
    ax.plot3D([P_w[0], views_pos[cam_idx,0]], 
                 [P_w[1], views_pos[cam_idx,1]], 
                 [P_w[2], views_pos[cam_idx, 2]], 'b-')
set_3d_axes_equal(ax)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
